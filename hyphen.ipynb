# %%
if __name__ == '__main__': 
    
    str = "Navya Rao"
    
    for i in range(0, len(str), 1): 
         
        if (str[i] == ' '): 
            str = str.replace(str[i], '-')         
    
    print(str)
# Out:
# Navya-Rao
